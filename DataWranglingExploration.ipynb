# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Loading Boston, Las Vegas and Charlotte data into a dataframe to normalize attributes and merge datasets

# %%
# %matplotlib inline

import os
import json
import time
import pickle
import requests


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
BostonData = '/Users/skhederian/restaurant-health/Data/boston_merged_try.csv'

#read the data into a dataframe
bosdf = pd.read_csv(BostonData, sep=",", encoding = 'utf-8', engine = 'python')
bosdf.head(5)

LasVegasData = '/Users/skhederian/restaurant-health/Data/lv_merged_try.csv'

#read the data into a dataframe
lvdf = pd.read_csv(LasVegasData, sep=",", encoding = 'utf-8', engine = 'python')
lvdf.head(5)

CharlotteData = '/Users/skhederian/restaurant-health/Data/charlotte_merged_try.csv'
#read the data into a dataframe
cdf = pd.read_csv(CharlotteData, sep=",", encoding = 'utf-8', engine = 'python')
cdf.head(5)
# Out:
#        rname                   address        date  Violations  \
# 0  Cafelatte  1 S MAIN Las Vegas 89101  2013-02-25         3.0
# 1  Cafelatte  1 S MAIN Las Vegas 89101  2014-06-26         6.0
# 2  Cafelatte  1 S MAIN Las Vegas 89101  2015-03-25         0.0
# 3  Cafelatte  1 S MAIN Las Vegas 89101  2014-06-26         6.0
# 4  Cafelatte  1 S MAIN Las Vegas 89101  2012-02-17         4.0
#
#                                   _id             business_id  \
# 0  ObjectId(581151a7b6729e7e3134f6dd)  ZwDkcflfYvyczQ7t-b8-wA
# 1  ObjectId(581151a7b6729e7e3134f6dd)  ZwDkcflfYvyczQ7t-b8-wA
# 2  ObjectId(581151a7b6729e7e3134f6dd)  ZwDkcflfYvyczQ7t-b8-wA
# 3  ObjectId(581151a7b6729e7e3134f6dd)  ZwDkcflfYvyczQ7t-b8-wA
# 4  ObjectId(581151a7b6729e7e3134f6dd)  ZwDkcflfYvyczQ7t-b8-wA
#
#                                  full_address  \
# 0  1 S Main St\nDowntown\nLas Vegas, NV 89101
# 1  1 S Main St\nDowntown\nLas Vegas, NV 89101
# 2  1 S Main St\nDowntown\nLas Vegas, NV 89101
# ...

# %%
ATTRIBUTES  = [
    "restaurant_name",
    "inspection_date",
    "violations",
    "city",
    "review_count",
    "neighborhoods",
    "longitude",
    "stars",
    "latitude"
]

# Describe the dataset
print(bosdf.describe())
print(lvdf.describe())
print(cdf.describe())
# Out:
#          violations  review_count     longitude         stars      latitude
# count  13111.000000  13111.000000  13111.000000  13111.000000  13111.000000
# mean       5.198612    129.808253    -71.079943      3.369232     42.340897
# std        4.996847    193.855126      0.033390      0.634746      0.025203
# min        1.000000      3.000000    -71.172687      1.500000     42.254554
# 25%        1.000000     21.000000    -71.095759      3.000000     42.335691
# 50%        4.000000     64.000000    -71.067747      3.500000     42.349358
# 75%        7.000000    167.000000    -71.057106      4.000000     42.355823
# max       56.000000   2302.000000    -70.996696      4.500000     42.389913
#         Violations  review_count    longitude        stars     latitude
# count  7996.000000   8042.000000  8042.000000  8042.000000  8042.000000
# mean      8.113057    127.515543  -115.132583     3.757399    36.096730
# std      12.162470    242.852037     0.978553     0.684287     0.230781
# ...
